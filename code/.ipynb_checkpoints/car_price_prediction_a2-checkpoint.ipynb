# %%
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Preparing the datasets

# %%
df = pd.read_csv('Cars.csv')
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
# Check unique values to see the categories
df['fuel'].unique(), df['seller_type'].unique(), df['transmission'].unique(), df['owner'].unique()
# Out:
# (array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object),
#  array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object),
#  array(['Manual', 'Automatic'], dtype=object),
#  array(['First Owner', 'Second Owner', 'Third Owner',
#         'Fourth & Above Owner', 'Test Drive Car'], dtype=object))

# %%
print("Dataset shape before dropping nan values: ", df.shape)
# Out:
# Dataset shape before dropping nan values:  (8128, 13)

# %%
df = df.dropna()
print("Dataset shape before after dropping nan values: ", df.shape)
# Out:
# Dataset shape before after dropping nan values:  (7906, 13)

# %%
# Define a mapping for categorical 'owner' values to numeric values
owner_map = {
    'First Owner': 1,
    'Second Owner': 2,
    'Third Owner': 3,
    'Fourth & Above Owner': 4,
    'Test Drive Car': 5
}

# Apply the mapping to the 'owner' column
# This replaces the categorical strings in 'owner' with their corresponding numeric values
df['owner'] = df['owner'].map(owner_map)

# Display unique values in the 'owner' column after mapping
# This helps verify that the mapping was applied correctly
df['owner'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
# For the feature fuel, remove all rows with CNG and LPG 
# because CNG and LPG use a different mileage system i.e., km/kg which is different from kmfeaturepl for Diesel and Petrol
df = df[~df["fuel"].isin(["CNG", "LPG"])]
df.shape
# Out:
# (7819, 13)

# %%
# For the feature mileage, remove “kmpl” and convert the column to numerical type (e.g., float).
df.mileage = df.mileage.str.split(' ').map(lambda x: float(x[0]))

# For the feature engine, remove “CC” and convert the column to numerical type (e.g., float)
df.engine = df.engine.str.split(' ').map(lambda x: float(x[0]))

# Do the same for max power
df.max_power = df.max_power.str.split(' ').map(lambda x: float(x[0]))

# For the feature brand, take only the first word and remove the rest
df.name = df.name.str.split(' ').map(lambda x: x[0])

df.head()
# Out:
#       name  year  selling_price  km_driven    fuel seller_type transmission  \
# 0   Maruti  2014         450000     145500  Diesel  Individual       Manual
# 1    Skoda  2014         370000     120000  Diesel  Individual       Manual
# 2    Honda  2006         158000     140000  Petrol  Individual       Manual
# 3  Hyundai  2010         225000     127000  Diesel  Individual       Manual
# 4   Maruti  2007         130000     120000  Petrol  Individual       Manual
#
#    owner  mileage  engine  max_power                    torque  seats
# 0      1    23.40  1248.0      74.00            190Nm@ 2000rpm    5.0
# 1      2    21.14  1498.0     103.52       250Nm@ 1500-2500rpm    5.0
# 2      3    17.70  1497.0      78.00     12.7@ 2,700(kgm@ rpm)    5.0
# 3      1    23.00  1396.0      90.00  22.4 kgm at 1750-2750rpm    5.0
# 4      1    16.10  1298.0      88.20     11.5@ 4,500(kgm@ rpm)    5.0

# %%
# Drop the feature torque
df = df.drop('torque', axis=1)

# Test Drive Cars are ridiculously expensive. Since we do not want to involve this, we will simply delete all samples related to it.
df = df.drop(df[df['owner'] == 5].index)

# %%
from sklearn.preprocessing import LabelEncoder

# Label Encode
le = LabelEncoder()
df['transmission'] = le.fit_transform(df['transmission'])

# %%
df.shape, df.owner.unique()
# Out:
# ((7814, 12), array([1, 2, 3, 4]))

# %%
df.head()
# Out:
#       name  year  selling_price  km_driven    fuel seller_type  transmission  \
# 0   Maruti  2014         450000     145500  Diesel  Individual             1
# 1    Skoda  2014         370000     120000  Diesel  Individual             1
# 2    Honda  2006         158000     140000  Petrol  Individual             1
# 3  Hyundai  2010         225000     127000  Diesel  Individual             1
# 4   Maruti  2007         130000     120000  Petrol  Individual             1
#
#    owner  mileage  engine  max_power  seats
# 0      1    23.40  1248.0      74.00    5.0
# 1      2    21.14  1498.0     103.52    5.0
# 2      3    17.70  1497.0      78.00    5.0
# 3      1    23.00  1396.0      90.00    5.0
# 4      1    16.10  1298.0      88.20    5.0

# %%
df.describe()
# Out:
#               year  selling_price     km_driven  transmission        owner  \
# count  7814.000000   7.814000e+03  7.814000e+03   7814.000000  7814.000000
# mean   2013.987074   6.515864e+05  6.916070e+04      0.867289     1.443819
# std       3.864426   8.097971e+05  5.687495e+04      0.339283     0.704962
# min    1994.000000   2.999900e+04  1.000000e+03      0.000000     1.000000
# 25%    2012.000000   2.700000e+05  3.400000e+04      1.000000     1.000000
# 50%    2015.000000   4.550000e+05  6.000000e+04      1.000000     1.000000
# 75%    2017.000000   6.950000e+05  9.600000e+04      1.000000     2.000000
# max    2020.000000   1.000000e+07  2.360457e+06      1.000000     4.000000
#
#            mileage       engine    max_power        seats
# count  7814.000000  7814.000000  7814.000000  7814.000000
# mean     19.391962  1462.914640    91.890230     5.421551
# std       4.001972   504.759742    35.727695     0.963125
# min       0.000000   624.000000    34.200000     2.000000
# 25%      16.780000  1197.000000    69.000000     5.000000
# 50%      19.300000  1248.000000    82.400000     5.000000
# 75%      22.320000  1582.000000   102.000000     5.000000
# max      42.000000  3604.000000   400.000000    14.000000

# %% [markdown]
# ### Feature Engineering

# %%
from sklearn.model_selection import train_test_split

# Feature Selection
X = df[['year', 'transmission', 'engine', 'max_power']]
y = np.array(np.log(df['selling_price']))

# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 102)

# %%
from sklearn.preprocessing import StandardScaler

# Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
import pickle

# Save Scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %% [markdown]
# ### Modelling

# %%
# Experiment tracking
import mlflow
import os

mlflow.set_tracking_uri("http://127.0.0.1:5000/")
# Set log name
os.environ["LOGNAME"] = "lou"
# Create mlflow experiment
mlflow.set_experiment(experiment_name="lou-linear-comparison")

if not os.path.exists("poly_transformer"):
    os.mkdir("poly_transformer")
# Out:
# 2025/02/04 20:57:36 INFO mlflow.tracking.fluent: Experiment with name 'lou-linear-comparison' does not exist. Creating a new experiment.

# %% [markdown]
# ### Task 1. Implementation

# %%
from sklearn.model_selection import KFold
from mlflow.models.signature import infer_signature

class LinearRegression(object):
    
    #in this class, we add cross validation as well for some spicy code....
    kfold = KFold(n_splits=3)
            
    def __init__(self, regularization, lr=0.001, method='batch', num_epochs=500, batch_size=50, 
                 cv=kfold, init_method="zeros", use_momentum=False, momentum=0.9, feature_names=None, degree=None, run_count=0):
        self.lr         = lr
        self.num_epochs = num_epochs
        self.batch_size = batch_size
        self.method     = method
        self.cv         = cv
        self.init_method = init_method
        self.regularization = regularization
        self.use_momentum = use_momentum
        self.momentum = momentum
        self.velocity = None # Momentum velocity term
        self.feature_names = feature_names
        self.run_count = run_count
        self.degree = degree
        if isinstance(self.degree, int):
            self.poly_transformer = PolynomialFeatures(degree=degree, include_bias=False)

    def mse(self, ytrue, ypred):
        ytrue = np.atleast_1d(ytrue)  
        ypred = np.atleast_1d(ypred)
    
        # Clip extreme values to prevent overflow
        diff = np.clip(ypred - ytrue, -1e10, 1e10)
        
        return np.mean(diff ** 2)

    def r2score(self, ytrue, ypred):
        tss = np.sum(np.square(np.clip(ytrue - np.mean(ytrue), -1e10, 1e10)))
        rss = np.sum(np.square(np.clip(ytrue - ypred, -1e10, 1e10)))
    
        return 1 - (rss / tss)

    def _initialize_weights(self, num_features):
        """
        Initializes weights using either 'zeros' or 'xavier' method.
        """
        if self.init_method == "zeros":
            return np.zeros(num_features)
        elif self.init_method == "xavier":
            lower, upper = - (1.0 / np.sqrt(num_features)), (1.0 / np.sqrt(num_features))
            return np.random.uniform(low=lower, high=upper, size=num_features)
        else:
            raise ValueError("Invalid init_method. Choose 'zeros' or 'xavier'.")
    
    def fit(self, X_train, y_train):
            
        #create a list of kfold scores
        self.kfold_scores = list()
        
        #reset val loss and val r2score
        self.val_loss_old = np.infty
        self.val_r2_old = -np.infty

        #kfold.split in the sklearn.....
        #5 splits
        for fold, (train_idx, val_idx) in enumerate(self.cv.split(X_train)):
                
            X_cross_train = X_train[train_idx]
            y_cross_train = y_train[train_idx]
            X_cross_val   = X_train[val_idx]
            y_cross_val   = y_train[val_idx]

            if isinstance(self.degree, int):
                X_cross_train = self.poly_transformer.fit_transform(X_cross_train)
                X_cross_val = self.poly_transformer.transform(X_cross_val)
            
            # Initialize weights based on user preference
            self.theta = self._initialize_weights(X_cross_train.shape[1])
            
            #define X_cross_train as only a subset of the data
            #how big is this subset?  => mini-batch size ==> 50
            
            #one epoch will exhaust the WHOLE training set
            with mlflow.start_run(run_name=f"run-{self.run_count}-fold-{fold}", nested=True):

                params = {"method": self.method, "lr": self.lr, "initialization": self.init_method, "momentum": self.use_momentum, "reg": type(self).__name__}
                mlflow.log_params(params=params)

                if isinstance(self.degree, int):
                    # Save and Log Polynomial Transformer
                    poly_transformer_path = f"poly_transformer/poly_transformer_run_{self.run_count}_fold_{fold}.pkl"
                    joblib.dump(self.poly_transformer, poly_transformer_path)
                    mlflow.log_artifact(poly_transformer_path, artifact_path=f"run_{self.run_count}_fold_{fold}_poly")
                          
                for epoch in range(self.num_epochs):
                
                    #with replacement or no replacement
                    #with replacement means just randomize
                    #with no replacement means 0:50, 51:100, 101:150, ......300:323
                    #shuffle your index
                    perm = np.random.permutation(X_cross_train.shape[0])
                            
                    X_cross_train = X_cross_train[perm]
                    y_cross_train = y_cross_train[perm]
                    
                    if self.method == 'sto':
                        for batch_idx in range(X_cross_train.shape[0]):
                            X_method_train = X_cross_train[batch_idx].reshape(1, -1) #(11,) ==> (1, 11) ==> (m, n)
                            y_method_train = y_cross_train[batch_idx] 
                            train_loss = self._train(X_method_train, y_method_train)
                    elif self.method == 'mini':
                        for batch_idx in range(0, X_cross_train.shape[0], self.batch_size):
                            #batch_idx = 0, 50, 100, 150
                            X_method_train = X_cross_train[batch_idx:batch_idx+self.batch_size, :]
                            y_method_train = y_cross_train[batch_idx:batch_idx+self.batch_size]
                            train_loss = self._train(X_method_train, y_method_train)
                    else:
                        X_method_train = X_cross_train
                        y_method_train = y_cross_train
                        train_loss = self._train(X_method_train, y_method_train)

                    mlflow.log_metric(key="train_loss", value=train_loss, step=epoch)

                    yhat_val = self.predict(X_cross_val)

                    # Compute metrics
                    val_loss_new = self.mse(y_cross_val, yhat_val)
                    val_r2_new = self.r2score(y_cross_val, yhat_val)
                    
                    mlflow.log_metric(key="val_loss", value=val_loss_new, step=epoch)
                    mlflow.log_metric(key="val_r2score", value=val_r2_new, step=epoch)
                    
                    #early stopping
                    if np.allclose(val_loss_new, self.val_loss_old):
                        break
                    self.val_loss_old = val_loss_new

                # Log model for this fold
                input_example = X_cross_train[:5]  # Sample input for inference
                y_pred_example = self.predict(input_example)
                signature = infer_signature(input_example, y_pred_example)
    
                mlflow.sklearn.log_model(self, artifact_path=f"run_{self.run_count}_fold_{fold}_model", signature=signature, input_example=input_example)
            
                self.kfold_scores.append(val_loss_new)
                print(f"Run: {self.run_count}, Fold: {fold} -> MSE: {val_loss_new:.4f}, R²: {val_r2_new:.4f}")
                        
    def _train(self, X, y):
        yhat = self.predict(X)
        m    = X.shape[0]        
        grad = (1/m) * X.T @(yhat - y)

        # Add regularization term only if a penalty is used
        if self.regularization is not None:
            grad += self.regularization.derivation(self.theta)

        # Apply Momentum-based Update if enabled
        if self.use_momentum:
            if self.velocity is None:
                self.velocity = np.zeros_like(self.theta)
            
            self.velocity = self.momentum * self.velocity + (1 - self.momentum) * grad
            self.theta = self.theta - self.lr * self.velocity
        else:
            self.theta = self.theta - self.lr * grad  # Standard Gradient Descent
        
        return self.mse(y, yhat)
    
    def predict(self, X):
        return X @ self.theta  #===>(m, n) @ (n, )
    
    def _coef(self):
        return self.theta[1:]  #remind that theta is (w0, w1, w2, w3, w4.....wn)

    def _bias(self):
        return self.theta[0]

    def _plot_feature_importance(self):
        """
        Plots feature importance based on absolute values of coefficients.
        Assumes features have been scaled for meaningful interpretation.
        """
        if self.theta is None:
            raise ValueError("Model has not been trained yet. Fit the model before calling this function.")

        feature_importance = np.abs(self._coef())  # Take absolute value of coefficients
        feature_names = self.feature_names if self.feature_names else [f"Feature {i}" for i in range(len(feature_importance))]

        # Sort by importance
        sorted_indices = np.argsort(feature_importance)[::-1]  # Descending order
        sorted_features = np.array(feature_names)[sorted_indices]
        sorted_importance = feature_importance[sorted_indices]

        # Plot
        plt.figure(figsize=(10, 5))
        plt.barh(sorted_features, sorted_importance, color='skyblue')
        plt.xlabel("Coefficient Magnitude (Feature Importance)")
        plt.ylabel("Features")
        plt.title("Feature Importance Based on Coefficients")
        plt.gca().invert_yaxis()  # Highest importance at top
        plt.show()

# %%
class LassoPenalty:
    def __init__(self, l):
        self.l = l # lambda value
        
    def __call__(self, theta): #__call__ allows us to call class as method
        return self.l * np.sum(np.abs(theta))
        
    def derivation(self, theta):
        return self.l * np.sign(theta)
    
class RidgePenalty:
    def __init__(self, l):
        self.l = l
        
    def __call__(self, theta): #__call__ allows us to call class as method
        return self.l * np.sum(np.square(theta))
        
    def derivation(self, theta):
        return self.l * 2 * theta
    
class ElasticPenalty:
    def __init__(self, l = 0.1, l_ratio = 0.5):
        self.l = l 
        self.l_ratio = l_ratio

    def __call__(self, theta):  #__call__ allows us to call class as method
        l1_contribution = self.l_ratio * self.l * np.sum(np.abs(theta))
        l2_contribution = (1 - self.l_ratio) * self.l * 0.5 * np.sum(np.square(theta))
        return (l1_contribution + l2_contribution)

    def derivation(self, theta):
        l1_derivation = self.l * self.l_ratio * np.sign(theta)
        l2_derivation = self.l * (1 - self.l_ratio) * theta
        return (l1_derivation + l2_derivation)
    
class Lasso(LinearRegression):
    def __init__(self, method, lr, l, init_method="zeros", use_momentum=False, run_count=0):
        self.regularization = LassoPenalty(l)
        super().__init__(self.regularization, lr, method, init_method=init_method, use_momentum=use_momentum, run_count=run_count)

class Ridge(LinearRegression):
    def __init__(self, method, lr, l, init_method="zeros", use_momentum=False, run_count=0):
        self.regularization = RidgePenalty(l)
        super().__init__(self.regularization, lr, method, init_method=init_method, use_momentum=use_momentum, run_count=run_count)

class ElasticNet(LinearRegression):
    def __init__(self, method, lr, l, l_ratio=0.5, init_method="zeros", use_momentum=False, run_count=0):
        self.regularization = ElasticPenalty(l, l_ratio)
        super().__init__(self.regularization, lr, method, init_method=init_method, use_momentum=use_momentum, run_count=run_count)

class PolynomialRegression(LinearRegression):
    def __init__(self, lr=0.001, method='batch', num_epochs=500, batch_size=50, init_method="zeros", 
                 use_momentum=False, momentum=0.9, degree=2, run_count=0):
        super().__init__(regularization=None, lr=lr, method=method, num_epochs=num_epochs, batch_size=batch_size, init_method=init_method, 
                         use_momentum=use_momentum, momentum=momentum, degree=degree, run_count=run_count)

# %% [markdown]
# ### Task 2. Experiment

# %%
import mlflow.sklearn
import numpy as np
from itertools import product
from sklearn.preprocessing import PolynomialFeatures

# Define hyperparameters to compare
regularization_methods = {
    "poly": PolynomialRegression, 
    "lasso": Lasso,
    "ridge": Ridge,
    "normal": LinearRegression,
    "elastic": ElasticNet
}
momentum_options = [False, True]
methods = ["batch", "mini", "sto"]
init_methods = ["zeros", "xavier"]
learning_rates = [0.01, 0.001, 0.0001]

run_count = 0
# Run experiments with MLflow tracking
for reg_name, reg_class in regularization_methods.items():
    for use_momentum, method, init_method, lr in product(momentum_options, methods, init_methods, learning_rates):

        # Create a descriptive run name
        run_name = f"{reg_name} | {method} | {init_method} | lr={lr} | momentum={use_momentum}"
        print(run_name)
            
        # Set regularization parameter (lambda)
        l = 0.1  # Common regularization strength
        l_ratio = 0.5  # ElasticNet L1/L2 ratio

        # Instantiate model
        if reg_name == "normal":
            model = LinearRegression(regularization=None, lr=lr, method=method, init_method=init_method, use_momentum=use_momentum, run_count=run_count)
        elif reg_name == "elastic":
            model = ElasticNet(method=method, lr=lr, l=l, l_ratio=l_ratio, init_method=init_method, use_momentum=use_momentum, run_count=run_count)
        elif reg_name == "poly":
            # # Transform the features using PolynomialFeatures
            model = PolynomialRegression(lr=lr, method=method, init_method=init_method, use_momentum=use_momentum, run_count=run_count)
        else:
            model = reg_class(method=method, lr=lr, l=l, init_method=init_method, use_momentum=use_momentum, run_count=run_count)

        run_count += 1
        
        model.fit(X_train, y_train)
# Out:
# poly | batch | zeros | lr=0.01 | momentum=False
# Run: 0, Fold: 0 -> MSE: 34.1096, R²: -49.7468
# 🏃 View run run-0-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/dfd2f4cff0c245c18fa9e8784b7c6f7e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 0, Fold: 1 -> MSE: 31.5614, R²: -47.5221
# 🏃 View run run-0-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/1908db9537bc4481ab57c66d5678713b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 0, Fold: 2 -> MSE: 33.1951, R²: -46.6663
# 🏃 View run run-0-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/bc6b344e25244814b24af0af122c59b6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | zeros | lr=0.001 | momentum=False
# Run: 1, Fold: 0 -> MSE: 81.8541, R²: -120.7790
# 🏃 View run run-1-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a98b12674b2649208e22de52998d7301
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 1, Fold: 1 -> MSE: 78.5491, R²: -119.7605
# 🏃 View run run-1-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/cef039d0bddc4a24abbdc9baddc5ef44
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 1, Fold: 2 -> MSE: 78.9828, R²: -112.4150
# 🏃 View run run-1-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/15c37fbe5f0447a198c93c059cfdf103
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | zeros | lr=0.0001 | momentum=False
# Run: 2, Fold: 0 -> MSE: 124.6782, R²: -184.4910
# 🏃 View run run-2-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/6cd29629e774486ea92ede2135a385a3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 2, Fold: 1 -> MSE: 124.1325, R²: -189.8398
# 🏃 View run run-2-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/dc334a0f0a134ee8b1fcbdd5fbc8ba95
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 2, Fold: 2 -> MSE: 122.7671, R²: -175.2870
# 🏃 View run run-2-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/b48c5bb07fdd48ba86553ee301434d99
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | xavier | lr=0.01 | momentum=False
# Run: 3, Fold: 0 -> MSE: 33.8233, R²: -49.3209
# 🏃 View run run-3-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/8614dbcd7f64468090c3b1e40109a6d0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 3, Fold: 1 -> MSE: 32.0088, R²: -48.2099
# 🏃 View run run-3-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/71ebcde3c7a34c38a30d791fceee2684
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 3, Fold: 2 -> MSE: 33.8360, R²: -47.5867
# 🏃 View run run-3-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/3629e52add7a4d64be236741910ded31
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | xavier | lr=0.001 | momentum=False
# Run: 4, Fold: 0 -> MSE: 83.3054, R²: -122.9383
# 🏃 View run run-4-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/ff2a4f24da1f49b78881d91fff4b1272
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 4, Fold: 1 -> MSE: 79.0347, R²: -120.5069
# 🏃 View run run-4-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/9335403ac705466983338ebfe1b1467a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 4, Fold: 2 -> MSE: 77.6524, R²: -110.5047
# 🏃 View run run-4-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/fc74a90ccb10453fbe791bb8fa41319e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | xavier | lr=0.0001 | momentum=False
# Run: 5, Fold: 0 -> MSE: 127.6683, R²: -188.9395
# 🏃 View run run-5-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/dd60b181f0014e998c3489cd50d3e9a6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 5, Fold: 1 -> MSE: 120.8655, R²: -184.8172
# 🏃 View run run-5-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/5bb8ef56d03f422d958099152fab5719
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 5, Fold: 2 -> MSE: 123.9491, R²: -176.9843
# 🏃 View run run-5-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/cc195a9f566f4f4ab912bcbe3c2a77b1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | zeros | lr=0.01 | momentum=False
# Run: 6, Fold: 0 -> MSE: 0.0875, R²: 0.8699
# 🏃 View run run-6-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/400dbbcd32e6404f9e4ca3559f542d18
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 6, Fold: 1 -> MSE: 0.0902, R²: 0.8613
# 🏃 View run run-6-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/085207be5f664c1fa610feb8af200b1e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 6, Fold: 2 -> MSE: 0.0864, R²: 0.8760
# 🏃 View run run-6-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/79eb7209cf1b4c28b9253e4da9c3c64c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | zeros | lr=0.001 | momentum=False
# Run: 7, Fold: 0 -> MSE: 0.5804, R²: 0.1364
# 🏃 View run run-7-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e4f4a7b1f993483ab50637465ad49a65
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 7, Fold: 1 -> MSE: 0.4711, R²: 0.2758
# 🏃 View run run-7-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/7f6d537035db465db6c9f1b3f9d2ca51
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 7, Fold: 2 -> MSE: 0.8384, R²: -0.2040
# 🏃 View run run-7-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e349bceb727a4febb27194b3f1c39e1d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | zeros | lr=0.0001 | momentum=False
# Run: 8, Fold: 0 -> MSE: 42.2676, R²: -61.8839
# 🏃 View run run-8-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/29ae8516f9d64b389c12b507c4f7c2bc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 8, Fold: 1 -> MSE: 39.4340, R²: -59.6253
# 🏃 View run run-8-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/51c56efbd1bc45b7a387a5c7c87d7a82
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 8, Fold: 2 -> MSE: 40.7889, R²: -57.5707
# 🏃 View run run-8-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/d317d8caf27f4eaaa6dc3b357c761a84
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | xavier | lr=0.01 | momentum=False
# Run: 9, Fold: 0 -> MSE: 0.0878, R²: 0.8694
# 🏃 View run run-9-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/d5d29300bccd4fadae3649ac377d1a74
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 9, Fold: 1 -> MSE: 0.0903, R²: 0.8611
# 🏃 View run run-9-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e2c09301337a4713bd6d5b4574fcc35a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 9, Fold: 2 -> MSE: 0.0857, R²: 0.8769
# 🏃 View run run-9-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/b85321319ff941c2aa6fdd005c6e2369
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | xavier | lr=0.001 | momentum=False
# Run: 10, Fold: 0 -> MSE: 0.5728, R²: 0.1478
# 🏃 View run run-10-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/75696f37ff204054849f76c9521cbcbe
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 10, Fold: 1 -> MSE: 0.4611, R²: 0.2911
# 🏃 View run run-10-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/3a512d8f1b8545f19d167706e3ff10bb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 10, Fold: 2 -> MSE: 0.8383, R²: -0.2038
# 🏃 View run run-10-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/2dcfabae873e4e4f93dacea484449098
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | xavier | lr=0.0001 | momentum=False
# Run: 11, Fold: 0 -> MSE: 42.2155, R²: -61.8065
# 🏃 View run run-11-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a3a75729d73647ce9c59fb2dd06c5193
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 11, Fold: 1 -> MSE: 39.6321, R²: -59.9300
# 🏃 View run run-11-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/2b0997c6f97a4ae799bc23d8d0854b71
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 11, Fold: 2 -> MSE: 41.2481, R²: -58.2300
# 🏃 View run run-11-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/6754e42a184949d18c6d39907ef2f22c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | zeros | lr=0.01 | momentum=False
# Run: 12, Fold: 0 -> MSE: 99999999999999983616.0000, R²: -148775795548030697472.0000
# 🏃 View run run-12-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c7ff1a022aa54b189167923a604caa68
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 12, Fold: 1 -> MSE: 99999999999999983616.0000, R²: -153738797845340913664.0000
# 🏃 View run run-12-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/dbc726a5bb5c4094b441f84e894918aa
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 12, Fold: 2 -> MSE: 99999999999999983616.0000, R²: -143594632835995500544.0000
# 🏃 View run run-12-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/3ceedbce2b444f4691cefbb9908a1dd6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | zeros | lr=0.001 | momentum=False
# Run: 13, Fold: 0 -> MSE: 0.0890, R²: 0.8676
# 🏃 View run run-13-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/bd97369cb4224c069bf04004fdb0086f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 13, Fold: 1 -> MSE: 0.0903, R²: 0.8611
# 🏃 View run run-13-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/ef968ed42bd34ae78f2e10d655660472
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 13, Fold: 2 -> MSE: 0.0862, R²: 0.8762
# 🏃 View run run-13-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/28710bee50eb478caae904cb6f528d71
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | zeros | lr=0.0001 | momentum=False
# Run: 14, Fold: 0 -> MSE: 0.0874, R²: 0.8700
# 🏃 View run run-14-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/25311130d74740e3b5d9cfeb17977a4c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 14, Fold: 1 -> MSE: 0.0901, R²: 0.8615
# 🏃 View run run-14-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/0e743fda5402477ba8bcf354e2cfb3bf
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 14, Fold: 2 -> MSE: 0.1083, R²: 0.8445
# 🏃 View run run-14-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/6e0eb47cc1bf42268be67303069f220d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | xavier | lr=0.01 | momentum=False
# Run: 15, Fold: 0 -> MSE: 99999999999999983616.0000, R²: -148775795548030697472.0000
# 🏃 View run run-15-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/51a11d368b99419394226ba4fc0023fb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 15, Fold: 1 -> MSE: 99999999999999983616.0000, R²: -153738797845340913664.0000
# 🏃 View run run-15-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/65c4e646fc5b448aaebfcff5107c02e3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 15, Fold: 2 -> MSE: 99999999999999983616.0000, R²: -143594632835995500544.0000
# 🏃 View run run-15-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/d265b4b423784021a28f582c27163634
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | xavier | lr=0.001 | momentum=False
# Run: 16, Fold: 0 -> MSE: 0.0878, R²: 0.8693
# 🏃 View run run-16-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/f7f33ede7b36478582f42e033099b633
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 16, Fold: 1 -> MSE: 0.0916, R²: 0.8592
# 🏃 View run run-16-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c69cf0992de44f09abd09ed30f877c6f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 16, Fold: 2 -> MSE: 0.0878, R²: 0.8739
# 🏃 View run run-16-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/aac2f7664b224fdcbf09af062035e746
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | xavier | lr=0.0001 | momentum=False
# Run: 17, Fold: 0 -> MSE: 0.0887, R²: 0.8680
# 🏃 View run run-17-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/9a99edbe8c6d48deaff880167929eb9b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 17, Fold: 1 -> MSE: 0.0918, R²: 0.8588
# 🏃 View run run-17-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/44f093572c4b4edb99a18248ec795b08
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 17, Fold: 2 -> MSE: 0.0856, R²: 0.8771
# 🏃 View run run-17-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/f9755c1e0a4f4617995318e30c2b418d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | zeros | lr=0.01 | momentum=True
# Run: 18, Fold: 0 -> MSE: 34.4015, R²: -50.1812
# 🏃 View run run-18-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/af3b718da30941cf87290e5b4b0a4ea5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 18, Fold: 1 -> MSE: 31.5206, R²: -47.4595
# 🏃 View run run-18-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c1404dd0b89b49d088582d59a9f0ff6b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 18, Fold: 2 -> MSE: 33.1616, R²: -46.6183
# 🏃 View run run-18-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/f6d2bef32849420196fa1aad79255fb8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | zeros | lr=0.001 | momentum=True
# Run: 19, Fold: 0 -> MSE: 82.0197, R²: -121.0255
# 🏃 View run run-19-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/39b3863e27db4cc39ce16e151f91cc91
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 19, Fold: 1 -> MSE: 78.4823, R²: -119.6578
# 🏃 View run run-19-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/9124621972244793a3a12a7e1e12c348
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 19, Fold: 2 -> MSE: 78.9242, R²: -112.3309
# 🏃 View run run-19-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/02deeb509184419db833466c48509cbf
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | zeros | lr=0.0001 | momentum=True
# Run: 20, Fold: 0 -> MSE: 124.8487, R²: -184.7446
# 🏃 View run run-20-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/75c337fd552243158bbc9a69c044ef0a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 20, Fold: 1 -> MSE: 124.0419, R²: -189.7005
# 🏃 View run run-20-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/8207f16441364e3f81e6f08424ad866e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 20, Fold: 2 -> MSE: 122.7066, R²: -175.2001
# 🏃 View run run-20-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a8ab957f06b24e31b6e1bf800a1d8a8d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | xavier | lr=0.01 | momentum=True
# Run: 21, Fold: 0 -> MSE: 34.0971, R²: -49.7283
# 🏃 View run run-21-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/4e67493a467546b58bc4b027f411fd18
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 21, Fold: 1 -> MSE: 31.7007, R²: -47.7362
# 🏃 View run run-21-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a94120dfd2ad4529bf0264f302e3af27
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 21, Fold: 2 -> MSE: 33.2857, R²: -46.7965
# 🏃 View run run-21-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/ee8e1390897b46bc8054430032c90b3e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | xavier | lr=0.001 | momentum=True
# Run: 22, Fold: 0 -> MSE: 82.5367, R²: -121.7946
# 🏃 View run run-22-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/1e8e8f70082943fbbc53b9d094c53f20
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 22, Fold: 1 -> MSE: 80.1621, R²: -122.2402
# 🏃 View run run-22-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a0646185c9c24aaeab20a7f282f0d9db
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 22, Fold: 2 -> MSE: 80.2096, R²: -114.1767
# 🏃 View run run-22-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/8e84ab00d5e04286bd2d35188c624f34
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | batch | xavier | lr=0.0001 | momentum=True
# Run: 23, Fold: 0 -> MSE: 128.4367, R²: -190.0828
# 🏃 View run run-23-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/348c97c7713a4b2ba64906783fa6ddc0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 23, Fold: 1 -> MSE: 124.9892, R²: -191.1568
# 🏃 View run run-23-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/15b150868e5b4f1d8a1a25ac57d29d9e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 23, Fold: 2 -> MSE: 126.5926, R²: -180.7802
# 🏃 View run run-23-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/fac9e30789a9481a95e615c318ef3a72
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | zeros | lr=0.01 | momentum=True
# Run: 24, Fold: 0 -> MSE: 0.0874, R²: 0.8699
# 🏃 View run run-24-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/4a431f17772d4240a40ed5570ada5de5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 24, Fold: 1 -> MSE: 0.0902, R²: 0.8613
# 🏃 View run run-24-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/4162879ce48d4c6aaf1967c5b690ac8f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 24, Fold: 2 -> MSE: 0.0862, R²: 0.8763
# 🏃 View run run-24-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/86bb5091966b4569b28e3dfa3bea32de
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | zeros | lr=0.001 | momentum=True
# Run: 25, Fold: 0 -> MSE: 0.5797, R²: 0.1375
# 🏃 View run run-25-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/7ba0336f414848a68754ce9b88f05650
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 25, Fold: 1 -> MSE: 0.4693, R²: 0.2785
# 🏃 View run run-25-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a43e96f76e6543f794328d84e0b82c65
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 25, Fold: 2 -> MSE: 0.8371, R²: -0.2021
# 🏃 View run run-25-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c23be83f45ae4c04940ee8fb5b7a4dfa
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | zeros | lr=0.0001 | momentum=True
# Run: 26, Fold: 0 -> MSE: 42.2687, R²: -61.8856
# 🏃 View run run-26-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/48b0703ee83c40afa253ed0bcf95f245
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 26, Fold: 1 -> MSE: 39.4387, R²: -59.6325
# 🏃 View run run-26-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/ab5a9b1e286d4947a9bd1280f9b2f079
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 26, Fold: 2 -> MSE: 40.7841, R²: -57.5638
# 🏃 View run run-26-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/ddb303eee39440c38d1f314cd16f3ad5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | xavier | lr=0.01 | momentum=True
# Run: 27, Fold: 0 -> MSE: 0.0873, R²: 0.8701
# 🏃 View run run-27-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/22bbeb2601b749b3807c1bcad0bf27d0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 27, Fold: 1 -> MSE: 0.0963, R²: 0.8520
# 🏃 View run run-27-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/363d3abaebcd4ef2bfa9bf7fa897db83
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 27, Fold: 2 -> MSE: 0.0861, R²: 0.8763
# 🏃 View run run-27-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/346fde4793ec4c9eabc078a182cf96cb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | xavier | lr=0.001 | momentum=True
# Run: 28, Fold: 0 -> MSE: 0.5692, R²: 0.1531
# 🏃 View run run-28-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/abd75c0c13904a29838a34c201bd3c91
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 28, Fold: 1 -> MSE: 0.4730, R²: 0.2728
# 🏃 View run run-28-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/feed83febb7347b0897b1b40effbf973
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 28, Fold: 2 -> MSE: 0.8481, R²: -0.2178
# 🏃 View run run-28-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/ddfefd2072e644748a46b3a95879f648
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | mini | xavier | lr=0.0001 | momentum=True
# Run: 29, Fold: 0 -> MSE: 41.7929, R²: -61.1778
# 🏃 View run run-29-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/8dbd34167ff44d28b70d7adeb0146a0e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 29, Fold: 1 -> MSE: 39.2318, R²: -59.3145
# 🏃 View run run-29-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/bf57d7ed3e3f48448cb46e5f511d05ca
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 29, Fold: 2 -> MSE: 40.5153, R²: -57.1778
# 🏃 View run run-29-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c666a2ff9c024bbcbd1a68c1835d0771
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | zeros | lr=0.01 | momentum=True
# Run: 30, Fold: 0 -> MSE: 99999999999999983616.0000, R²: -148775795548030697472.0000
# 🏃 View run run-30-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/cfd1976a67bc42f0925098c8c84b2535
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 30, Fold: 1 -> MSE: 99999999999999983616.0000, R²: -153738797845340913664.0000
# 🏃 View run run-30-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/b8283e6bbc1149699cf55147f8b4a741
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 30, Fold: 2 -> MSE: 99999999999999983616.0000, R²: -143594632835995500544.0000
# 🏃 View run run-30-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/44f1113523d745878134ea625daa7204
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | zeros | lr=0.001 | momentum=True
# Run: 31, Fold: 0 -> MSE: 0.0881, R²: 0.8689
# 🏃 View run run-31-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/d24ec2a704ed49a4a9825054a18ee409
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 31, Fold: 1 -> MSE: 0.0924, R²: 0.8580
# 🏃 View run run-31-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/0f1d58854f454e6ba0cfdfbe253723c7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 31, Fold: 2 -> MSE: 0.0860, R²: 0.8765
# 🏃 View run run-31-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/64dadf20126d48f1aba3ab00c4c355b2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | zeros | lr=0.0001 | momentum=True
# Run: 32, Fold: 0 -> MSE: 0.0876, R²: 0.8697
# 🏃 View run run-32-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e61a478fb4e8487689f3151939bd705b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 32, Fold: 1 -> MSE: 0.0899, R²: 0.8618
# 🏃 View run run-32-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/714d26605949492889b80b3198ce30c5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 32, Fold: 2 -> MSE: 0.0858, R²: 0.8768
# 🏃 View run run-32-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/6d5e785406954b89be576f52af2c535d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | xavier | lr=0.01 | momentum=True
# Run: 33, Fold: 0 -> MSE: 99999999999999983616.0000, R²: -148775795548030697472.0000
# 🏃 View run run-33-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/03454a68d1fa45c9bd0838b9f8fa3c71
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 33, Fold: 1 -> MSE: 99999999999999983616.0000, R²: -153738797845340913664.0000
# 🏃 View run run-33-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/3c52b1cd7a3245cfa3fd5446e7437f5a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 33, Fold: 2 -> MSE: 99999999999999983616.0000, R²: -143594632835995500544.0000
# 🏃 View run run-33-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/1c93e5c3495e4119a5edd7316c31ba2f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | xavier | lr=0.001 | momentum=True
# Run: 34, Fold: 0 -> MSE: 0.0879, R²: 0.8692
# 🏃 View run run-34-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/768105c453eb4704b59887e56cf61962
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 34, Fold: 1 -> MSE: 0.0906, R²: 0.8608
# 🏃 View run run-34-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/98574166317f438aab1936e927c24c10
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 34, Fold: 2 -> MSE: 0.0862, R²: 0.8762
# 🏃 View run run-34-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/6cfed46265b6457092edc39a182ba9d3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# poly | sto | xavier | lr=0.0001 | momentum=True
# Run: 35, Fold: 0 -> MSE: 0.0873, R²: 0.8701
# 🏃 View run run-35-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/3e5f90ab7f4949a6b4f9be3950ecd1ef
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 35, Fold: 1 -> MSE: 0.0902, R²: 0.8614
# 🏃 View run run-35-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/04f7eaea097443799c810b537bcd8394
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 35, Fold: 2 -> MSE: 0.0856, R²: 0.8770
# 🏃 View run run-35-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a7e883d20daf42d8bdb5abf7075b9f47
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | zeros | lr=0.01 | momentum=False
# Run: 36, Fold: 0 -> MSE: 169.1544, R²: -250.6608
# 🏃 View run run-36-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/9680896ea5a143c5b838aad9d8783304
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 36, Fold: 1 -> MSE: 169.3183, R²: -259.3080
# 🏃 View run run-36-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a3899638457c49db95e6c7feee153aa1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 36, Fold: 2 -> MSE: 169.0066, R²: -241.6844
# 🏃 View run run-36-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/bf109972d7e34a77a8f16b3550cd1b9f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | zeros | lr=0.001 | momentum=False
# Run: 37, Fold: 0 -> MSE: 169.3209, R²: -250.9085
# 🏃 View run run-37-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/26a69b4b9296499eb5174ea4ac28f0c3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 37, Fold: 1 -> MSE: 169.6346, R²: -259.7942
# 🏃 View run run-37-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/3531e213962643ee9f5edbb17eb24a6b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 37, Fold: 2 -> MSE: 169.2976, R²: -242.1023
# 🏃 View run run-37-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/eae84982d7414ddea888cb1763232103
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | zeros | lr=0.0001 | momentum=False
# Run: 38, Fold: 0 -> MSE: 169.3232, R²: -250.9120
# 🏃 View run run-38-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/2bdae91d354b4f2cadf71c610565f00e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 38, Fold: 1 -> MSE: 169.6375, R²: -259.7986
# 🏃 View run run-38-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/14098a08f903401a9855227ed0a5a62c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 38, Fold: 2 -> MSE: 169.3005, R²: -242.1064
# 🏃 View run run-38-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c85a9f1a72574d48826d50322ae94f97
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | xavier | lr=0.01 | momentum=False
# Run: 39, Fold: 0 -> MSE: 169.3444, R²: -250.9435
# 🏃 View run run-39-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e12281c28d234b09bfb3824ed1df8496
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 39, Fold: 1 -> MSE: 169.1613, R²: -259.0666
# 🏃 View run run-39-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/36502caad00848aaafb5b34797e99c60
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 39, Fold: 2 -> MSE: 169.0235, R²: -241.7086
# 🏃 View run run-39-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/89298d5663c64729807b5755bebd5a7b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | xavier | lr=0.001 | momentum=False
# Run: 40, Fold: 0 -> MSE: 169.5294, R²: -251.2187
# 🏃 View run run-40-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/b4f157f44e2d48aa8fa27c3a78aa5ddc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 40, Fold: 1 -> MSE: 170.2491, R²: -260.7389
# 🏃 View run run-40-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/bf7618407a5b4c5094c7edacac07ddb8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 40, Fold: 2 -> MSE: 169.3276, R²: -242.1454
# 🏃 View run run-40-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e3affebea31840e191334b4127922bfc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | xavier | lr=0.0001 | momentum=False
# Run: 41, Fold: 0 -> MSE: 169.9791, R²: -251.8878
# 🏃 View run run-41-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/ddd272d54eb640bc933f80de6c25a28f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 41, Fold: 1 -> MSE: 169.6528, R²: -259.8221
# 🏃 View run run-41-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/797d2b349a004c6c9b1b3851dc97fedb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 41, Fold: 2 -> MSE: 170.4559, R²: -243.7655
# 🏃 View run run-41-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/dc9af37d360a4c5281d6c26d4c056deb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | mini | zeros | lr=0.01 | momentum=False
# Run: 42, Fold: 0 -> MSE: 169.2070, R²: -250.7390
# 🏃 View run run-42-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/6ea44b9a64a74b3e94c9f686497d462e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 42, Fold: 1 -> MSE: 169.3314, R²: -259.3281
# 🏃 View run run-42-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/36b58bb1fc834b44a061c3a0742b8afa
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 42, Fold: 2 -> MSE: 168.9978, R²: -241.6717
# 🏃 View run run-42-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/d945d710031f4850a05875a1325613be
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | mini | zeros | lr=0.001 | momentum=False
# Run: 43, Fold: 0 -> MSE: 169.1581, R²: -250.6663
# 🏃 View run run-43-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/bc5413bdce6c425980e92afda47919fe
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 43, Fold: 1 -> MSE: 169.2829, R²: -259.2534
# 🏃 View run run-43-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/0beaea4150724e918bcd543b6cdd4280
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 43, Fold: 2 -> MSE: 168.9887, R²: -241.6587
# 🏃 View run run-43-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/b62bfd439f034f3d9a99b3d55ad916ea
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | mini | zeros | lr=0.0001 | momentum=False
# Run: 44, Fold: 0 -> MSE: 169.1638, R²: -250.6747
# 🏃 View run run-44-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/b03ad52d09084778bac424f8991853a9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 44, Fold: 1 -> MSE: 169.3362, R²: -259.3354
# 🏃 View run run-44-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a3cab7b1e45449bfbfd8de93a443f3ba
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 44, Fold: 2 -> MSE: 169.0176, R²: -241.7003
# 🏃 View run run-44-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/f1639403436d41c798ac61d895f35875
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | mini | xavier | lr=0.01 | momentum=False
# Run: 45, Fold: 0 -> MSE: 169.1864, R²: -250.7085
# 🏃 View run run-45-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/fad0cbe5f9394eac95b00e04a13f1281
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 45, Fold: 1 -> MSE: 169.2510, R²: -259.2045
# 🏃 View run run-45-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/89a416afc94f4713834dc27841c888fb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 45, Fold: 2 -> MSE: 169.1839, R²: -241.9390
# 🏃 View run run-45-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/228a53e021d64f1cb2a5f768356b91d2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | mini | xavier | lr=0.001 | momentum=False
# Run: 46, Fold: 0 -> MSE: 169.1253, R²: -250.6175
# 🏃 View run run-46-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/95d0d199432847a4861ccbebf7b44731
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 46, Fold: 1 -> MSE: 169.2901, R²: -259.2646
# 🏃 View run run-46-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/6306a99978534d12861d6c86070ca9af
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 46, Fold: 2 -> MSE: 168.9899, R²: -241.6604
# 🏃 View run run-46-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/2b33a2c9c51040018234aac4b23023d0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | mini | xavier | lr=0.0001 | momentum=False
# Run: 47, Fold: 0 -> MSE: 169.2600, R²: -250.8180
# 🏃 View run run-47-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/1cd840b8a7c747449a5aeb0d51dd664a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 47, Fold: 1 -> MSE: 169.4997, R²: -259.5868
# 🏃 View run run-47-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a0a51d1ce6db4d6cb794210a55041ff8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 47, Fold: 2 -> MSE: 168.9296, R²: -241.5738
# 🏃 View run run-47-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/04699bf1682543b6862679666cda91f7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | sto | zeros | lr=0.01 | momentum=False
# Run: 48, Fold: 0 -> MSE: 171.5354, R²: -254.2031
# 🏃 View run run-48-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/640e97edf81649c89087c078013f69ea
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 48, Fold: 1 -> MSE: 170.7810, R²: -261.5566
# 🏃 View run run-48-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/dbdcbb0f766a4bf59e9185e773464b15
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 48, Fold: 2 -> MSE: 176.3930, R²: -252.2909
# 🏃 View run run-48-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/f5a175cb280f4c249f41f1635b70a1f2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | sto | zeros | lr=0.001 | momentum=False
# Run: 49, Fold: 0 -> MSE: 169.3942, R²: -251.0175
# 🏃 View run run-49-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/61e10c0da0344c318c267efba056ced4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 49, Fold: 1 -> MSE: 169.4164, R²: -259.4588
# 🏃 View run run-49-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/3b2234a0ebc04d50a9a14ce5f4ce46dc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 49, Fold: 2 -> MSE: 169.0541, R²: -241.7526
# 🏃 View run run-49-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/2f92373963324f269c6cc681282d96ca
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | sto | zeros | lr=0.0001 | momentum=False
# Run: 50, Fold: 0 -> MSE: 169.1923, R²: -250.7172
# 🏃 View run run-50-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/2aa9ad146a42478994a28b23bc0f99c6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 50, Fold: 1 -> MSE: 169.3083, R²: -259.2925
# 🏃 View run run-50-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/935bedfb3ffa4bc88cd503932fcddb7c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 50, Fold: 2 -> MSE: 169.1664, R²: -241.9138
# 🏃 View run run-50-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/18355454744945229d9dd96407eaaca1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | sto | xavier | lr=0.01 | momentum=False
# Run: 51, Fold: 0 -> MSE: 172.5484, R²: -255.7102
# 🏃 View run run-51-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/1aa6eb71c9154405adb0fd0db277d033
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 51, Fold: 1 -> MSE: 171.8572, R²: -263.2111
# 🏃 View run run-51-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e3dff905963f414e93a56df9d8c64ca2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 51, Fold: 2 -> MSE: 170.9249, R²: -244.4390
# 🏃 View run run-51-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/31bd413890d84af3bf75c9c5c53ada03
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | sto | xavier | lr=0.001 | momentum=False
# Run: 52, Fold: 0 -> MSE: 169.2267, R²: -250.7683
# 🏃 View run run-52-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/92943962a0914350a9c7dad81067bc22
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 52, Fold: 1 -> MSE: 169.3242, R²: -259.3170
# 🏃 View run run-52-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/4d1b916fa492461aacccf107bf0b4c56
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 52, Fold: 2 -> MSE: 168.9119, R²: -241.5484
# 🏃 View run run-52-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/1e51bdddb5784f00b5a5f6a32661ff69
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | sto | xavier | lr=0.0001 | momentum=False
# Run: 53, Fold: 0 -> MSE: 169.1987, R²: -250.7267
# 🏃 View run run-53-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/9989f80d86e64caa9cb82a5912eef9e7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 53, Fold: 1 -> MSE: 169.3533, R²: -259.3618
# 🏃 View run run-53-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/7c02f724286146ffacfdfe2634202b19
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 53, Fold: 2 -> MSE: 169.1227, R²: -241.8511
# 🏃 View run run-53-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/993b92a7df094a31bd957b3dccdc0c84
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | zeros | lr=0.01 | momentum=True
# Run: 54, Fold: 0 -> MSE: 169.1461, R²: -250.6484
# 🏃 View run run-54-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/ca91804c6a0641dda880e3d27b102cf2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 54, Fold: 1 -> MSE: 169.2708, R²: -259.2349
# 🏃 View run run-54-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/dc8e3d4e19db49bdae41c74d970467ae
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 54, Fold: 2 -> MSE: 168.9802, R²: -241.6465
# 🏃 View run run-54-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/08fdbd7eb4d8481ebaab96b2992194e4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | zeros | lr=0.001 | momentum=True
# Run: 55, Fold: 0 -> MSE: 169.3231, R²: -250.9118
# 🏃 View run run-55-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c58d20c81c5a47cab1bba7639ce7ce39
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 55, Fold: 1 -> MSE: 169.6366, R²: -259.7972
# 🏃 View run run-55-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e15b49fbf3dc4e25b74a0d929db2b28f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 55, Fold: 2 -> MSE: 169.2990, R²: -242.1042
# 🏃 View run run-55-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/fa4f59c8feed4a0888ac427cdfd1f4b3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | zeros | lr=0.0001 | momentum=True
# Run: 56, Fold: 0 -> MSE: 169.3235, R²: -250.9123
# 🏃 View run run-56-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/f5c831bf4bf047f9b3937283c0882c8d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 56, Fold: 1 -> MSE: 169.6377, R²: -259.7989
# 🏃 View run run-56-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/0372c646affb48bbac23a8818f9d4f38
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 56, Fold: 2 -> MSE: 169.3006, R²: -242.1066
# 🏃 View run run-56-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/1d69967fa626458c900743dceb8eb62f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | xavier | lr=0.01 | momentum=True
# Run: 57, Fold: 0 -> MSE: 169.2284, R²: -250.7709
# 🏃 View run run-57-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/add71c93aa0a4e9dbf021dad17627749
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 57, Fold: 1 -> MSE: 169.0482, R²: -258.8927
# 🏃 View run run-57-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c2406bf74276478e86e7f710988f2859
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 57, Fold: 2 -> MSE: 169.0759, R²: -241.7839
# 🏃 View run run-57-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/dfe519c80deb46309cf223dece83e207
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | xavier | lr=0.001 | momentum=True
# Run: 58, Fold: 0 -> MSE: 169.9166, R²: -251.7948
# 🏃 View run run-58-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/41b58ef58fc64fe8bc4eb87f03b7e60f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 58, Fold: 1 -> MSE: 170.2076, R²: -260.6751
# 🏃 View run run-58-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c95b6f450b4a4b9a8b792909457b9c60
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 58, Fold: 2 -> MSE: 169.3949, R²: -242.2420
# 🏃 View run run-58-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/6e144d6952e845748f024d38c5a11e7d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | batch | xavier | lr=0.0001 | momentum=True
# Run: 59, Fold: 0 -> MSE: 168.9048, R²: -250.2895
# 🏃 View run run-59-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/92f2c724422d4c689661000cd1310706
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 59, Fold: 1 -> MSE: 169.3951, R²: -259.4260
# 🏃 View run run-59-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/79b80138c7404bb3b3d350cee6700081
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 59, Fold: 2 -> MSE: 168.9509, R²: -241.6045
# 🏃 View run run-59-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/4017a93b55bf4c568ba475480ea51443
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# lasso | mini | zeros | lr=0.01 | momentum=True
# Run: 60, Fold: 0 -> MSE: 169.2404, R²: -250.7888
# 🏃 View run run-60-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/d2c9cc3cb9554d2abea92aa2ebeb1253
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 60, Fold: 1 -> MSE: 169.3285, R²: -259.3236
# ...
# Run: 160, Fold: 0 -> MSE: 169.3304, R²: -250.9226
# 🏃 View run run-160-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/1f2956f882064539a75bf16a108b62d7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 160, Fold: 1 -> MSE: 169.9372, R²: -260.2594
# 🏃 View run run-160-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/debc2348a7d240aeba8c2cdde8032c2b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 160, Fold: 2 -> MSE: 169.3347, R²: -242.1555
# 🏃 View run run-160-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/7f7e13df435943cea700776a29aadc96
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | sto | xavier | lr=0.0001 | momentum=False
# Run: 161, Fold: 0 -> MSE: 169.3021, R²: -250.8806
# 🏃 View run run-161-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/639bb818d3cb4aa38dc8d41c08daf14a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 161, Fold: 1 -> MSE: 169.2802, R²: -259.2493
# 🏃 View run run-161-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/d3cb3f0216cd4ff69e0b4bff88c6f969
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 161, Fold: 2 -> MSE: 169.1047, R²: -241.8252
# 🏃 View run run-161-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/ccea126dc6144bfab0c7375f93798355
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | batch | zeros | lr=0.01 | momentum=True
# Run: 162, Fold: 0 -> MSE: 169.1286, R²: -250.6224
# 🏃 View run run-162-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/fb55b7304f494b35952617178aadff56
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 162, Fold: 1 -> MSE: 169.2422, R²: -259.1910
# 🏃 View run run-162-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e94adf58f9d44aeb9164906f0baa5658
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 162, Fold: 2 -> MSE: 168.9398, R²: -241.5885
# 🏃 View run run-162-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/343e307f280f45e8ad7dee9687312664
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | batch | zeros | lr=0.001 | momentum=True
# Run: 163, Fold: 0 -> MSE: 169.3231, R²: -250.9118
# 🏃 View run run-163-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a04b1c21e8ec4e84bc2c5ddf64b93954
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 163, Fold: 1 -> MSE: 169.6365, R²: -259.7971
# 🏃 View run run-163-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a6028847ee1a4cd08659bc066258bc40
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 163, Fold: 2 -> MSE: 169.2989, R²: -242.1041
# 🏃 View run run-163-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/725a8c35a17243cdb3fef445cd503023
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | batch | zeros | lr=0.0001 | momentum=True
# Run: 164, Fold: 0 -> MSE: 169.3234, R²: -250.9123
# 🏃 View run run-164-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/f82ea506025543729241cc85ec4fd7fa
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 164, Fold: 1 -> MSE: 169.6377, R²: -259.7989
# 🏃 View run run-164-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/7a3df2a40f9b45ac945b0947a5fa9eca
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 164, Fold: 2 -> MSE: 169.3006, R²: -242.1066
# 🏃 View run run-164-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/0ef79bc4052e46f7954cc60dde105404
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | batch | xavier | lr=0.01 | momentum=True
# Run: 165, Fold: 0 -> MSE: 169.5211, R²: -251.2063
# 🏃 View run run-165-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/937cf06b3fa34e93874ddadf509c0c2e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 165, Fold: 1 -> MSE: 169.4718, R²: -259.5439
# 🏃 View run run-165-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/57678c02e7e84053b5d8891c8af94708
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 165, Fold: 2 -> MSE: 168.6848, R²: -241.2223
# 🏃 View run run-165-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/b6bfc6cc119448f08bd79c8e7c8c1c58
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | batch | xavier | lr=0.001 | momentum=True
# Run: 166, Fold: 0 -> MSE: 169.2596, R²: -250.8173
# 🏃 View run run-166-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/583eeadd95aa46f1ac47613469f2e1dc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 166, Fold: 1 -> MSE: 170.0046, R²: -260.3630
# 🏃 View run run-166-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/619178fcb63f46b78ed6e1bcda575200
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 166, Fold: 2 -> MSE: 169.9586, R²: -243.0514
# 🏃 View run run-166-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/95196711c5b34ced9e8d818cd85ef57d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | batch | xavier | lr=0.0001 | momentum=True
# Run: 167, Fold: 0 -> MSE: 170.3012, R²: -252.3670
# 🏃 View run run-167-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/07d0d02347564da7b8bb3b1b50179d6d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 167, Fold: 1 -> MSE: 169.7165, R²: -259.9201
# 🏃 View run run-167-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/8aa908085bdc4214b33024a56e11c52a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 167, Fold: 2 -> MSE: 168.8125, R²: -241.4057
# 🏃 View run run-167-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/8a480cf78ff94350b4e2a2a8b4a38ea5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | mini | zeros | lr=0.01 | momentum=True
# Run: 168, Fold: 0 -> MSE: 169.2790, R²: -250.8462
# 🏃 View run run-168-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/cdf3d7d084b34b08826411c3a23b5ed2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 168, Fold: 1 -> MSE: 169.2475, R²: -259.1991
# 🏃 View run run-168-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/378efd3f48734b65a8bd5d3891e52434
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 168, Fold: 2 -> MSE: 169.2219, R²: -241.9935
# 🏃 View run run-168-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/7755afa0d71c4dee801610066e0fd9f3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | mini | zeros | lr=0.001 | momentum=True
# Run: 169, Fold: 0 -> MSE: 169.1364, R²: -250.6340
# 🏃 View run run-169-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e980cef4e4d244729b50ac24cb0a35f1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 169, Fold: 1 -> MSE: 169.2647, R²: -259.2255
# 🏃 View run run-169-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/d5103c061427445aa1603875126661a9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 169, Fold: 2 -> MSE: 168.9523, R²: -241.6064
# 🏃 View run run-169-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/8f5931c27ad74374b841b20b494262cb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | mini | zeros | lr=0.0001 | momentum=True
# Run: 170, Fold: 0 -> MSE: 169.1512, R²: -250.6560
# 🏃 View run run-170-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/7437d0e8574247e7ad959919d8775e1b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 170, Fold: 1 -> MSE: 169.3280, R²: -259.3228
# 🏃 View run run-170-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/43f0949068a7450fafe5cfbc77483117
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 170, Fold: 2 -> MSE: 169.0012, R²: -241.6767
# 🏃 View run run-170-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/4efcf999d7204d7aa14ff4b073cf1083
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | mini | xavier | lr=0.01 | momentum=True
# Run: 171, Fold: 0 -> MSE: 169.2632, R²: -250.8226
# 🏃 View run run-171-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/57c42db086744093ad8e63c01bf1c7bf
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 171, Fold: 1 -> MSE: 169.2520, R²: -259.2060
# 🏃 View run run-171-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/075d6095554b4ce5a3bd1cce9df2afec
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 171, Fold: 2 -> MSE: 169.1484, R²: -241.8880
# 🏃 View run run-171-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/6da52604d8314a64996bcd5101e4ef2b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | mini | xavier | lr=0.001 | momentum=True
# Run: 172, Fold: 0 -> MSE: 169.2698, R²: -250.8325
# 🏃 View run run-172-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/df34fb5f4da74841b98d5f0bb6c36974
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 172, Fold: 1 -> MSE: 169.2286, R²: -259.1700
# 🏃 View run run-172-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/7cdcee7f43ee424cb38c0708a0e70062
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 172, Fold: 2 -> MSE: 169.0004, R²: -241.6755
# 🏃 View run run-172-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/cba6300dd84240059338f5626f5b9114
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | mini | xavier | lr=0.0001 | momentum=True
# Run: 173, Fold: 0 -> MSE: 169.2699, R²: -250.8327
# 🏃 View run run-173-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c0dc1ef7739d41109fb73fc7930f001d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 173, Fold: 1 -> MSE: 169.3465, R²: -259.3513
# 🏃 View run run-173-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/02dd4a96cc024f748ee196a21f34a87c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 173, Fold: 2 -> MSE: 168.7511, R²: -241.3176
# 🏃 View run run-173-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/906cdce49b474de9b6c0fa3bfd929dd7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | sto | zeros | lr=0.01 | momentum=True
# Run: 174, Fold: 0 -> MSE: 176.1247, R²: -261.0309
# 🏃 View run run-174-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/1d306b36b614457a9c64354f4e985878
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 174, Fold: 1 -> MSE: 171.2701, R²: -262.3087
# 🏃 View run run-174-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/409eb07b0bd142acbdbf9f1b472f341a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 174, Fold: 2 -> MSE: 170.7937, R²: -244.2506
# 🏃 View run run-174-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/f413e2bbe95341feb088cd841a607fa9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | sto | zeros | lr=0.001 | momentum=True
# Run: 175, Fold: 0 -> MSE: 169.2376, R²: -250.7846
# 🏃 View run run-175-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/c628caa3b08a4734a1e7b5a24ad8432a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 175, Fold: 1 -> MSE: 169.8377, R²: -260.1065
# 🏃 View run run-175-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/d369d7f3036c400fb06f5da78c71f135
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 175, Fold: 2 -> MSE: 169.0961, R²: -241.8129
# 🏃 View run run-175-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/ef5f6acada494d89b5de34ce7b1db37f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | sto | zeros | lr=0.0001 | momentum=True
# Run: 176, Fold: 0 -> MSE: 169.2673, R²: -250.8287
# 🏃 View run run-176-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/cc85443952954b28b55356c61cd4c9ca
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 176, Fold: 1 -> MSE: 169.2698, R²: -259.2334
# 🏃 View run run-176-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/b17aa3e7068c42aab60ed2900442328b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 176, Fold: 2 -> MSE: 169.0879, R²: -241.8012
# 🏃 View run run-176-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/d6e6cc43229547418be8223ffd9bf15c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | sto | xavier | lr=0.01 | momentum=True
# Run: 177, Fold: 0 -> MSE: 186.9690, R²: -277.1646
# 🏃 View run run-177-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/aa9640b596eb4122bb1f257fb902d6b2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 177, Fold: 1 -> MSE: 169.2125, R²: -259.1452
# 🏃 View run run-177-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/a815f3c521164f98980111bdd7110338
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 177, Fold: 2 -> MSE: 170.2784, R²: -243.5106
# 🏃 View run run-177-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/4d4ce1a0eefd4953955410285cbe6600
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | sto | xavier | lr=0.001 | momentum=True
# Run: 178, Fold: 0 -> MSE: 169.3889, R²: -251.0097
# 🏃 View run run-178-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/fbda4f58a4774d95a4dfed0aad4aab2f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 178, Fold: 1 -> MSE: 169.7284, R²: -259.9384
# 🏃 View run run-178-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/90404601343f44f4ab0467e5aa8c4311
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 178, Fold: 2 -> MSE: 169.0815, R²: -241.7920
# 🏃 View run run-178-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/5f6e37a658eb40d3bf22b8309004565a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# elastic | sto | xavier | lr=0.0001 | momentum=True
# Run: 179, Fold: 0 -> MSE: 169.2626, R²: -250.8218
# 🏃 View run run-179-fold-0 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/3922c8b0d9814cd7891882e5c1549f18
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 179, Fold: 1 -> MSE: 169.2629, R²: -259.2228
# 🏃 View run run-179-fold-1 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/e6030cc0c40a4e28853fad16e9c03d0b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553
# Run: 179, Fold: 2 -> MSE: 169.0964, R²: -241.8134
# 🏃 View run run-179-fold-2 at: http://127.0.0.1:5000/#/experiments/336865229606055553/runs/dae668ffe54047b6bd86be1b0bd98374
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/336865229606055553

# %% [markdown]
# ## Perform prediction on test set using the best model

# %%
# Load all runs from the experiment
experiment_name = "lou-linear-comparison"  # Update with your actual experiment name
experiment = mlflow.get_experiment_by_name(experiment_name)
runs = mlflow.search_runs(experiment_ids=[experiment.experiment_id])

# Filter only completed runs
runs = runs[runs["status"] == "FINISHED"]

# Sort runs by best validation loss (lower is better)
best_run = runs.sort_values("metrics.val_loss").iloc[0]

# Get the run ID of the best model
best_run_id = best_run["run_id"]

print(f"Best Model Run ID: {best_run_id}")
print(f"Best Model Validation Loss: {best_run['metrics.val_loss']}")
print(f"Best Model Validation R² Score: {best_run['metrics.val_r2score']}")
# Out:
# Best Model Run ID: f9755c1e0a4f4617995318e30c2b418d
# Best Model Validation Loss: 0.08561634601863873
# Best Model Validation R² Score: 0.8770595222869403

# %%
from glob import glob

best_model_path = glob(f"mlartifacts/{experiment.experiment_id}/{best_run_id}/artifacts/*_model")[0]
print(best_model_path)

# Load the best model from MLflow
best_model = mlflow.sklearn.load_model(best_model_path)

print("Best model loaded successfully!")
# Out:
# mlartifacts/336865229606055553/f9755c1e0a4f4617995318e30c2b418d/artifacts/run_17_fold_2_model
# Best model loaded successfully!

# %%
# Path to polynomial transformer artifact in MLflow
poly_transformer_path = "poly_transformer/poly_transformer_run_17_fold_2.pkl"

# Load the fitted polynomial transformer
poly_transformer = joblib.load(poly_transformer_path)

print("Polynomial transformer loaded successfully!")
# Out:
# Polynomial transformer loaded successfully!

# %%
# Transform test set using the loaded polynomial transformer
X_test_transformed = poly_transformer.transform(X_test)

# Make predictions
y_pred = best_model.predict(X_test_transformed)

print("MSE on test data: ", best_model.mse(y_test, y_pred)) # Compute MSE
print("R²score on test data: ", best_model.r2score(y_test, y_pred)) # Compute R2score
# Out:
# MSE on test data:  0.08054246378377629
# R²score on test data:  0.8862818146297029

# %% [markdown]
# ## Feature Importance

# %%
# As normal features are transformed into polynomial features, we can only see feature importance for transformed features
best_model._plot_feature_importance()

# %% [markdown]
# ## Report
#
# The MLflow experiment was conducted to evaluate different regression models, including Polynomial Regression, Lasso, Ridge, and Normal Regression. Multiple runs were executed, and the performance metrics were logged for each fold. The experiment tracked validation loss (val_loss), training loss (train_loss), and R² score (val_r2score) to assess model accuracy and generalization.
#
# The best-performing model in terms of validation loss and R² score was Polynomial Regression (run-17-fold-2), which achieved a validation loss of 0.0856 and a validation R² score of 0.8771. This model was trained with stochastic gradient descent (sto), Xavier initialization, and a learning rate of 0.0001. The training progress plots indicate a rapid decline in loss during early epochs, suggesting effective convergence. The R² score stabilizes after the initial training phase, confirming that the model captures the variance in the data well.
#
# Overall, the experiment successfully identified Polynomial Regression as the most effective model under the tested conditions. Future improvements could include fine-tuning hyperparameters or exploring additional regularization techniques to further optimize performance.

# %% [markdown]
# <div style="display: flex; justify-content: space-between;">
#   <img src="images/run_names.png" alt="Image 1" style="width: 33.3%;">
#   <img src="images/best_run_logs.png" alt="Image 2" style="width: 33.3%;">
#   <img src="images/training_progress.png" alt="Image 3" style="width: 33.3%;">
# </div>

# %%
# Define the experiment name or ID
experiment_name = "lou-linear-comparison"
experiment = mlflow.get_experiment_by_name(experiment_name)
experiment_id = experiment.experiment_id

# Search all runs in the experiment
runs_df = mlflow.search_runs(experiment_ids=[experiment_id])

# Filter for relevant models
model_types = ["PolynomialRegression", "Lasso", "Ridge", "LinearRegression", "ElasticNet"]
best_models = {}

# Iterate through each model type and find the best model based on validation loss
for model in model_types:
    model_runs = runs_df[runs_df["params.reg"] == model]
    if not model_runs.empty:
        best_run = model_runs.loc[model_runs["metrics.val_loss"].idxmin()]
        best_models[model] = {
            "run_id": best_run["run_id"],
            "val_loss": best_run["metrics.val_loss"],
            "val_r2score": best_run["metrics.val_r2score"],
            "train_loss": best_run["metrics.train_loss"],
            "momentum": best_run["params.momentum"],
            "initialization": best_run["params.initialization"],
            "learning_rate": best_run["params.lr"],
            "method": best_run["params.method"]
        }

# Convert best models dictionary into a DataFrame
best_models_df = pd.DataFrame.from_dict(best_models, orient="index")
best_models_df.head()
# Out:
#                                                 run_id    val_loss  \
# PolynomialRegression  f9755c1e0a4f4617995318e30c2b418d    0.085616
# Lasso                 6c6571fe7e414f92a65cf8d95b993713  168.759238
# Ridge                 9f71427e40bd47418b1cfbaaa39c9fa2  168.693621
# LinearRegression      b9538c44c47044498c3914879998470e  168.540396
# ElasticNet            b6bfc6cc119448f08bd79c8e7c8c1c58  168.684780
#
#                       val_r2score  train_loss momentum initialization  \
# PolynomialRegression     0.877060    0.205345    False         xavier
# Lasso                 -241.329208  170.753861     True         xavier
# Ridge                 -249.975277  167.259446     True         xavier
# LinearRegression      -241.014962  169.362231     True         xavier
# ElasticNet            -241.222291  169.226390     True         xavier
#
#                      learning_rate method
# PolynomialRegression        0.0001    sto
# Lasso                        0.001   mini
# Ridge                        0.001   mini
# LinearRegression             0.001  batch
# ElasticNet                    0.01  batch

# %% [markdown]
# The table above presents the best-performing models from an MLflow experiment evaluating various regression techniques, including Polynomial Regression, Lasso, Ridge, Linear Regression, and ElasticNet. Among them, Polynomial Regression significantly outperforms the other models, achieving the lowest validation loss (0.0856) and the highest validation R² score (0.8771). This suggests that the model effectively captures the variance in the data, while the other models exhibit extremely high validation loss values, indicating poor generalization.
#
# The Polynomial Regression model was trained using stochastic gradient descent (sto) with Xavier initialization and a learning rate of 0.0001, without momentum. Meanwhile, the other models, trained using mini-batch or batch gradient descent with momentum enabled, struggled with validation loss values exceeding 168, resulting in highly negative R² scores, which indicate that these models perform worse than a simple mean-based predictor. These findings highlight the suitability of polynomial features in this dataset, reinforcing the need for feature transformations rather than conventional regularized linear models.
